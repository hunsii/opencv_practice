# %% [markdown]
# # 17. 이미지 검출 (경계선)

# %% [markdown]
# ## Canny Edge Detection

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('snowman.png')

canny = cv2.Canny(img, 150, 200)
# 대상 이미지, minVal (하위 임계값), maxVal (상위 임계값)

plt.figure(figsize=(16, 16))
plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(canny, cv2.COLOR_BGR2RGB))

# %%
import cv2
import matplotlib.pyplot as plt

def empty(pos):
    pass

img = cv2.imread('snowman.png')

name = "Trackbar"
cv2.namedWindow(name)
cv2.createTrackbar('threshold1', name, 0, 255, empty) # minVal
cv2.createTrackbar('threshold2', name, 0, 255, empty) # minVal

while True:
    threshold1 = cv2.getTrackbarPos('threshold1', name)
    threshold2 = cv2.getTrackbarPos('threshold2', name)
    
    canny = cv2.Canny(img, threshold1, threshold2)
    # 대상 이미지, minVal (하위 임계값), maxVal (상위 임계값)
    
    cv2.imshow('img', img)
    cv2.imshow(name, canny)
    
    if cv2.waitKey(1) == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3728/2721193057.py in <module>
#      13
#      14 while True:
# ---> 15     threshold1 = cv2.getTrackbarPos('threshold1', name)
#      16     threshold2 = cv2.getTrackbarPos('threshold2', name)
#      17
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2581: error: (-27:Null pointer) NULL window: 'Trackbar' in function 'cvGetTrackbarPos'
