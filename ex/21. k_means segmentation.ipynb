# %% [markdown]
# # 21. k_means segmentation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../img/beach.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.subplot(1, 2, 1)
plt.figure(figsize = (16, 16))
plt.imshow(img_rgb)

# %%
vectorized = img.reshape((-1, 3))
vectorized = np.float32(vectorized)
vectorized.shape
# Out:
# (261042, 3)

# %%
vectorized
# Out:
# array([[106., 212., 176.],
#        [ 94., 196., 161.],
#        [130., 220., 190.],
#        ...,
#        [ 99., 107.,  54.],
#        [114., 126.,  68.],
#        [100., 115.,  54.]], dtype=float32)

# %%
K= 2

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
            # 종료조건, 최대 반복할 횟수, 정확도
    
            # cv2.TERM_CRITERIA_EPS : 주어진 정확도에 도달하면 반복 중단
            # cv2.TERM_CRITERIA_MAX_ITER : 인자에 지정된 횟수만큼 반복하고 중단
            # 더하기로 연결하면 두 조건 중 하나 (or 연산)가 만족되면 중단된다.

attempts = 10
ret, label, center = cv2.kmeans(vectorized, K, None, criteria, attempts, cv2.KMEANS_PP_CENTERS)

center = np.uint8(center)
res = center[label.flatten()]
result = res.reshape((img.shape))

figure_size = 15
plt.figure(figsize = (16, 16))
plt.title("K = 2")
plt.axis('off') # 축 정보 제거
plt.imshow(result)

# %%
K= 3

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)

attempts = 10
ret, label, center = cv2.kmeans(vectorized, K, None, criteria, attempts, cv2.KMEANS_PP_CENTERS)

center = np.uint8(center)
res = center[label.flatten()]
result = res.reshape((img.shape))

figure_size = 15
plt.figure(figsize = (16, 16))
plt.title("K = 2")
plt.axis('off') # 축 정보 제거
plt.imshow(result)

# %%
K= 5

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)

attempts = 10
ret, label, center = cv2.kmeans(vectorized, K, None, criteria, attempts, cv2.KMEANS_PP_CENTERS)

center = np.uint8(center)
res = center[label.flatten()]
result = res.reshape((img.shape))

figure_size = 15
plt.figure(figsize = (16, 16))
plt.title("K = 2")
plt.axis('off') # 축 정보 제거
plt.imshow(result)
